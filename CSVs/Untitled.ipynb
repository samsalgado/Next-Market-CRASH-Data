# %%
import pandas as pd
from sklearn.neural_network import MLPClassifier
df=pd.read_csv('US CPI.csv')
df
# Out:
#          Yearmon      CPI
# 0     01-01-1913    9.800
# 1     01-02-1913    9.800
# 2     01-03-1913    9.800
# 3     01-04-1913    9.800
# 4     01-05-1913    9.700
# ...          ...      ...
# 1298  01-03-2021  264.877
# 1299  01-04-2021  267.054
# 1300  01-05-2021  269.195
# 1301  01-06-2021  271.696
# 1302  01-07-2021  273.003
#
# [1303 rows x 2 columns]

# %%
df = pd.read_csv('US CPI.csv')
X = df.drop(columns = ['CPI'])
X
y = df['CPI']
y
# Out:
# 0         9.800
# 1         9.800
# 2         9.800
# 3         9.800
# 4         9.700
#          ...
# 1298    264.877
# 1299    267.054
# 1300    269.195
# 1301    271.696
# 1302    273.003
# Name: CPI, Length: 1303, dtype: float64

# %%
df_1 = pd.read_csv('data.csv')
df_1
# Out:
#        saledate      MA   type  bedrooms
# 0    30/09/2007  441854  house         2
# 1    31/12/2007  441854  house         2
# 2    31/03/2008  441854  house         2
# 3    30/06/2008  441854  house         2
# 4    30/09/2008  451583  house         2
# ..          ...     ...    ...       ...
# 342  30/09/2018  603281   unit         3
# 343  31/12/2018  601167   unit         3
# 344  31/03/2019  605637   unit         3
# 345  30/06/2019  599339   unit         3
# 346  30/09/2019  597884   unit         3
#
# [347 rows x 4 columns]

# %%
df_2 = pd.read_csv('usprice_cust.csv')
df_2
# Out:
#    Median and Average Sales Prices of New Homes Sold in United States  \
# 0                                                 NaN
# 1                                         Annual Data
# 2                                                 NaN
# 3                                              Period
# 4                                                1963
# ..                                                ...
# 61                                               2020
# 62                                               2021
# 63                                                NaN
# 64                                                NaN
# 65           Note: The sales price includes the land.
#
#    Unnamed: 1 Unnamed: 2
# 0         NaN        NaN
# 1         NaN        NaN
# 2         NaN        NaN
# 3     Median     Average
# 4     $18,000    $19,300
# ..        ...        ...
# 61   $336,900   $391,900
# 62   $392,900   $453,700
# 63        NaN        NaN
# 64        NaN        NaN
# ...

# %%
df_2.describe()
# Out:
#        Median and Average Sales Prices of New Homes Sold in United States  \
# count                                                  62
# unique                                                 62
# top                                           Annual Data
# freq                                                    1
#
#        Unnamed: 1 Unnamed: 2
# count          60         60
# unique         59         59
# top      $120,000    $26,600
# freq            2          2

# %%
df_3 = pd.read_csv('housesSold.csv')
df_3
total_sold_2021 = 762
# Out:
#                                 Houses Sold by Region          Unnamed: 1  \
# 0                                                 NaN                 NaN
# 1                                         Annual Data                 NaN
# 2                                                 NaN                 NaN
# 3   (Components may not add to total because of ro...                 NaN
# 4                                              Period  Sold during period
# ..                                                ...                 ...
# 66                                               2021                 762
# 67                                                NaN                 NaN
# 68                                                NaN                 NaN
# 69  Note: Estimates prior to 1999 include an upwar...                 NaN
# 70  houses sold in permit-issuing areas that will ...                 NaN
#
#    Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# ...

# %%
df.values
# Out:
# array([['01-01-1913', 9.8],
#        ['01-02-1913', 9.8],
#        ['01-03-1913', 9.8],
#        ...,
#        ['01-05-2021', 269.195],
#        ['01-06-2021', 271.696],
#        ['01-07-2021', 273.003]], dtype=object)

# %%
df_1.drop()
# Out:
#   Input In [15]
#     Signature:
#               ^
# SyntaxError: invalid syntax

# %%
df.insurance = pd.read_csv('insurance.csv')
df.insurance
# Out:
# C:\Users\samue\AppData\Local\Temp\ipykernel_21460\2503892623.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.insurance = pd.read_csv('insurance.csv')
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# ...

# %%
df_income = pd.read_csv('CPI_Report.csv')
df_income #UNnamed is first 12 months of the year, followed by Half1(Quarter1 and Quarter2) and Half2(Quarter3 and Quarter4)
# Out:
#    CPI for All Urban Consumers (CPI-U)  \
# 0                  Original Data Value
# 1                                  NaN
# 2                           Series Id:
# 3              Not Seasonally Adjusted
# 4                        Series Title:
# 5                                Area:
# 6                                Item:
# 7                         Base Period:
# 8                               Years:
# 9                                  NaN
# 10                                Year
# 11                                2000
# 12                                2001
# 13                                2002
# 14                                2003
# 15                                2004
# 16                                2005
# 17                                2006
# 18                                2007
# 19                                2008
# 20                                2009
# 21                                2010
# 22                                2011
# ...

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
df_income = pd.read_csv('CPI_Report.csv')
X = df_income.drop(columns = ['Unnamed: 13'])
#Unnamed:13 is Quarter 1 and Quarter 2
y = df_income['Unnamed: 13']
y
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10      HALF1
# 11      170.8
# 12      176.6
# 13      178.9
# 14      183.3
# 15      187.6
# 16      193.2
# 17      200.6
# 18    205.709
# 19    214.429
# 20    213.139
# 21    217.535
# 22    223.598
# 23    228.850
# 24    232.366
# 25    236.384
# 26    236.265
# 27    238.778
# 28    244.076
# 29    250.089
# 30    254.412
# 31    257.557
# 32    266.236
# 33        NaN
# Name: Unnamed: 13, dtype: object

# %%
df_income = pd.read_csv('CPI_Report.csv')
X = df_income.drop(columns = ['Unnamed: 14'])
X
y = df_income['Unnamed: 14']
y #Unnamed:14 is Quarter 3 and Quarter 4, Columns are by month
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10      HALF2
# 11      173.6
# 12      177.5
# 13      180.9
# 14      184.6
# 15      190.2
# 16      197.4
# 17      202.6
# 18    208.976
# 19    216.177
# 20    215.935
# 21    218.576
# 22    226.280
# 23    230.338
# 24    233.548
# 25    237.088
# 26    237.769
# 27    241.237
# 28    246.163
# 29    252.125
# 30    256.903
# 31    260.065
# 32    275.703
# 33        NaN
# Name: Unnamed: 14, dtype: object

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
df_income = pd.read_csv('CPI_Report.csv')
X = df_income.drop(columns=[ 'Unnamed: 14'])
X
y = df_income['Unnamed: 14']
y
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [68], in <module>
#       6 y = df_income['Unnamed: 14']
#       7 model = DecisionTreeClassifier()
# ----> 8 model.fit(X,y)
#       9 predictions = model.predict([[32, 275.703]])
#      10 predictions
#
# File ~\miniconda3\lib\site-packages\sklearn\tree\_classes.py:937, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     899 def fit(
#     900     self, X, y, sample_weight=None, check_input=True, X_idx_sorted="deprecated"
#     901 ):
#     902     """Build a decision tree classifier from the training set (X, y).
#     903
#     904     Parameters
#    (...)
#     934         Fitted estimator.
#     935     """
# --> 937     super().fit(
#     938         X,
#     939         y,
#     940         sample_weight=sample_weight,
#     941         check_input=check_input,
# ...

# %%
df
# Out:
#          Yearmon      CPI
# 0     01-01-1913    9.800
# 1     01-02-1913    9.800
# 2     01-03-1913    9.800
# 3     01-04-1913    9.800
# 4     01-05-1913    9.700
# ...          ...      ...
# 1298  01-03-2021  264.877
# 1299  01-04-2021  267.054
# 1300  01-05-2021  269.195
# 1301  01-06-2021  271.696
# 1302  01-07-2021  273.003
#
# [1303 rows x 2 columns]

# %%
X = df.drop(columns = ['CPI'])
X
y = df['CPI']
y
# Out:
# 0         9.800
# 1         9.800
# 2         9.800
# 3         9.800
# 4         9.700
#          ...
# 1298    264.877
# 1299    267.054
# 1300    269.195
# 1301    271.696
# 1302    273.003
# Name: CPI, Length: 1303, dtype: float64

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
df_book = pd.read_csv('Book1.csv')
df_book
CPI_data = pd.read_csv('Book1.csv')
X = CPI_data.drop(columns=['CPI'])
y = CPI_data['CPI']
