# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime
df=pd.read_csv('US CPI.csv')
df
# Out:
#           Date      CPI
# 0     1/1/1913    9.800
# 1     1/2/1913    9.800
# 2     1/3/1913    9.800
# 3     1/4/1913    9.800
# 4     1/5/1913    9.700
# ...        ...      ...
# 1298  1/3/2021  264.877
# 1299  1/4/2021  267.054
# 1300  1/5/2021  269.195
# 1301  1/6/2021  271.696
# 1302  1/7/2021  273.003
#
# [1303 rows x 2 columns]

# %%
import pandas as pd
df = pd.read_csv('US CPI.csv')
X = df.drop(columns = ['CPI'])
X
y = df['CPI']
y
# Out:
# 0         9.800
# 1         9.800
# 2         9.800
# 3         9.800
# 4         9.700
#          ...
# 1298    264.877
# 1299    267.054
# 1300    269.195
# 1301    271.696
# 1302    273.003
# Name: CPI, Length: 1303, dtype: float64

# %%
df_1 = pd.read_csv('data.csv')
df_1
MA_EndDate_graph = {2007:441854, 2008:603281, 2009:442131, 2017:506578, 2018:601167, 2019:597884}
Years = list(MA_EndDate_graph.keys())
Moving_Avg = list(MA_EndDate_graph.values())
plt.bar(Years,Moving_Avg)
# Out:
# <BarContainer object of 6 artists>

# %%
import pandas as pd
df_1 = pd.read_csv('data.csv')
df_1
X = df_1.drop(columns=[ 'MA'])
X
y = df_1['MA']
y
# Out:
# 0      441854
# 1      441854
# 2      441854
# 3      441854
# 4      451583
#         ...
# 342    603281
# 343    601167
# 344    605637
# 345    599339
# 346    597884
# Name: MA, Length: 347, dtype: int64

# %%
import pandas as pd
df_2 = pd.read_csv('usprice_cust.csv')
df_2
# Out:
#    Median and Average Sales Prices of New Homes Sold in United States  \
# 0                                                 NaN
# 1                                         Annual Data
# 2                                                 NaN
# 3                                              Period
# 4                                                1963
# ..                                                ...
# 61                                               2020
# 62                                               2021
# 63                                                NaN
# 64                                                NaN
# 65           Note: The sales price includes the land.
#
#    Unnamed: 1 Unnamed: 2
# 0         NaN        NaN
# 1         NaN        NaN
# 2         NaN        NaN
# 3     Median     Average
# 4     $18,000    $19,300
# ..        ...        ...
# 61   $336,900   $391,900
# 62   $392,900   $453,700
# 63        NaN        NaN
# 64        NaN        NaN
# ...

# %%
df_2.describe()
# Out:
#        Median and Average Sales Prices of New Homes Sold in United States  \
# count                                                  62
# unique                                                 62
# top                                           Annual Data
# freq                                                    1
#
#        Unnamed: 1 Unnamed: 2
# count          60         60
# unique         59         59
# top      $120,000    $26,600
# freq            2          2

# %%
import pandas as pd
df_3 = pd.read_csv('housesSold.csv')
df_3
total_sold_2021 = 762
df_3.isna().any()
# Out:
# Houses Sold by Region    True
# Unnamed: 1               True
# Unnamed: 2               True
# Unnamed: 3               True
# Unnamed: 4               True
# Unnamed: 5               True
# dtype: bool

# %%
df_income = pd.read_csv('CPI_Report.csv')
df_income #UNnamed is first 12 months of the year, followed by Half1(Quarter1 and Quarter2) and Half2(Quarter3 and Quarter4)
# Out:
#     Year      Jan      Feb      Mar      Apr      May      Jun      Jul  \
# 0   2000  168.800  169.800  171.200  171.300  171.500  172.400  172.800
# 1   2001  175.100  175.800  176.200  176.900  177.700  178.000  177.500
# 2   2002  177.100  177.800  178.800  179.800  179.800  179.900  180.100
# 3   2003  181.700  183.100  184.200  183.800  183.500  183.700  183.900
# 4   2004  185.200  186.200  187.400  188.000  189.100  189.700  189.400
# 5   2005  190.700  191.800  193.300  194.600  194.400  194.500  195.400
# 6   2006  198.300  198.700  199.800  201.500  202.500  202.900  203.500
# 7   2007  202.416  203.499  205.352  206.686  207.949  208.352  208.299
# 8   2008  211.080  211.693  213.528  214.823  216.632  218.815  219.964
# 9   2009  211.143  212.193  212.709  213.240  213.856  215.693  215.351
# 10  2010  216.687  216.741  217.631  218.009  218.178  217.965  218.011
# 11  2011  220.223  221.309  223.467  224.906  225.964  225.722  225.922
# ...

# %%
import pandas as pd

df_income = pd.read_csv('CPI_Report.csv')
df_income
# Out:
#     Year      Jan      Feb      Mar      Apr      May      Jun      Jul  \
# 0   2000  168.800  169.800  171.200  171.300  171.500  172.400  172.800
# 1   2001  175.100  175.800  176.200  176.900  177.700  178.000  177.500
# 2   2002  177.100  177.800  178.800  179.800  179.800  179.900  180.100
# 3   2003  181.700  183.100  184.200  183.800  183.500  183.700  183.900
# 4   2004  185.200  186.200  187.400  188.000  189.100  189.700  189.400
# 5   2005  190.700  191.800  193.300  194.600  194.400  194.500  195.400
# 6   2006  198.300  198.700  199.800  201.500  202.500  202.900  203.500
# 7   2007  202.416  203.499  205.352  206.686  207.949  208.352  208.299
# 8   2008  211.080  211.693  213.528  214.823  216.632  218.815  219.964
# 9   2009  211.143  212.193  212.709  213.240  213.856  215.693  215.351
# 10  2010  216.687  216.741  217.631  218.009  218.178  217.965  218.011
# 11  2011  220.223  221.309  223.467  224.906  225.964  225.722  225.922
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
df_income = pd.read_csv('CPI_Report.csv')
X = df_income.drop(columns=[ 'HALF2'])
X
yearly_CPI_2000_2021 = df_income['HALF2']
yearly_CPI_2000_2021
# Out:
# 0     173.600
# 1     177.500
# 2     180.900
# 3     184.600
# 4     190.200
# 5     197.400
# 6     202.600
# 7     208.976
# 8     216.177
# 9     215.935
# 10    218.576
# 11    226.280
# 12    230.338
# 13    233.548
# 14    237.088
# 15    237.769
# 16    241.237
# 17    246.163
# 18    252.125
# 19    256.903
# 20    260.065
# 21    275.703
# 22        NaN
# Name: HALF2, dtype: float64

# %%
df_4 = pd.read_csv('US CPI.csv')
df_4
df_4.tail()
# Out:
#           Date      CPI
# 1298  1/3/2021  264.877
# 1299  1/4/2021  267.054
# 1300  1/5/2021  269.195
# 1301  1/6/2021  271.696
# 1302  1/7/2021  273.003

# %%
import pandas as pd
df = pd.read_csv('US CPI.csv')
df
X = df.drop(columns = ['CPI'])
X
y = df['CPI']
y
# Out:
# 0         9.800
# 1         9.800
# 2         9.800
# 3         9.800
# 4         9.700
#          ...
# 1298    264.877
# 1299    267.054
# 1300    269.195
# 1301    271.696
# 1302    273.003
# Name: CPI, Length: 1303, dtype: float64

# %%
df_book = pd.read_csv('Book1.csv')
df_book
# Out:
#           Nation  High CPI  Inflation Rate                CPI  Year  \
# 0         Turkey         1           48.69              760.5  2022
# 1            USA         1            7.50            280.148  2022
# 2      Venezuela         1         1198.00  2,750,974,554,036  2022
# 3          Sudan         1          340.00               9138  2021
# 4       Zimbabwe         1           60.70               6490  2021
# 5          Syria         1          139.00               2668  2022
# 6       Suriname         1           63.30             775.92  2021
# 7      Argentina         1           51.20             605.03  2022
# 8           Iran         1           35.20              388.2  2022
# 9       Ethiopia         1           33.00             398.65  2022
# 10        Rwanda         0           -2.00              163.7  2022
# 11          Chad         0           -0.05             123.42  2021
# 12         Gabon         0            0.60              87.53  2022
# ...

# %%
X = df_book.drop(columns=['Inflation Rate'])
X
y = df_book['Inflation Rate']
y
# Out:
# 0       48.69
# 1        7.50
# 2     1198.00
# 3      340.00
# 4       60.70
# 5      139.00
# 6       63.30
# 7       51.20
# 8       35.20
# 9       33.00
# 10      -2.00
# 11      -0.05
# 12       0.60
# 13       0.60
# 14       0.70
# 15       1.80
# 16       0.90
# 17       1.10
# Name: Inflation Rate, dtype: float64

# %%
X = df_book.drop(columns=['CPI'])
X
y = df_book['CPI']
y
# Out:
# 0                 760.5
# 1               280.148
# 2     2,750,974,554,036
# 3                  9138
# 4                  6490
# 5                  2668
# 6                775.92
# 7                605.03
# 8                 388.2
# 9                398.65
# 10                163.7
# 11               123.42
# 12                87.53
# 13                100.3
# 14               116.04
# 15               128.07
# 16               151.29
# 17                85.64
# Name: CPI, dtype: object

# %% [markdown]
# from sklearn.tree import DecisionTreeClassifier
# import numpy as np
# import pandas as pd
# from sklearn.model_selection import train_test_split
# df_book_inflation_rate_by_country = pd.read_csv('Book1.csv')
# df_book_inflation_rates_by_country

# %% [markdown]
# Infl_rate_CPI = {48.69:760.5, 7.50:280.148, 1198:2750974554036,51.20:605.03,1.10:85.64, 33.00:398.65, 0.60:87.53, 0.60:100.3}
# Rate = list(Infl_rate_CPI.keys())
# CPI = list(Infl_rate_CPI.values())
# plt.bar(Rate,CPI)
# plt.show()

# %%
 # %pylab
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime
df_cpi_report = pd.read_csv('CPI_Report.csv')
df_cpi_report
df_cpi_report.head()
# Out:
# Using matplotlib backend: <object object at 0x0000024AD29E9450>
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
#    Year    Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep    Oct  \
# 0  2000  168.8  169.8  171.2  171.3  171.5  172.4  172.8  172.8  173.7  174.0
# 1  2001  175.1  175.8  176.2  176.9  177.7  178.0  177.5  177.5  178.3  177.7
# 2  2002  177.1  177.8  178.8  179.8  179.8  179.9  180.1  180.7  181.0  181.3
# 3  2003  181.7  183.1  184.2  183.8  183.5  183.7  183.9  184.6  185.2  185.0
# 4  2004  185.2  186.2  187.4  188.0  189.1  189.7  189.4  189.5  189.9  190.9
#
#      Nov    Dec  HALF1  HALF2
# 0  174.1  174.0  170.8  173.6
# 1  177.4  176.7  176.6  177.5
# 2  181.3  180.9  178.9  180.9
# 3  184.5  184.3  183.3  184.6
# 4  191.0  190.3  187.6  190.2

# %%
df_cpi_report.tail()
# Out:
#     Year      Jan      Feb      Mar      Apr      May      Jun      Jul  \
# 18  2018  247.867  248.991  249.554  250.546  251.588  251.989  252.006
# 19  2019  251.712  252.776  254.202  255.548  256.092  256.143  256.571
# 20  2020  257.971  258.678  258.115  256.389  256.394  257.797  259.101
# 21  2021  261.582  263.014  264.877  267.054  269.195  271.696  273.003
# 22  2022  281.148      NaN      NaN      NaN      NaN      NaN      NaN
#
#         Aug      Sep      Oct      Nov      Dec    HALF1    HALF2
# 18  252.146  252.439  252.885  252.038  251.233  250.089  252.125
# 19  256.558  256.759  257.346  257.208  256.974  254.412  256.903
# 20  259.918  260.280  260.388  260.229  260.474  257.557  260.065
# 21  273.567  274.310  276.589  277.948  278.802  266.236  275.703
# 22      NaN      NaN      NaN      NaN      NaN      NaN      NaN

# %%
df_cpi_report['Jan'].plot(figsize=(22,2))
# Out:
# <AxesSubplot:>

# %%
df_cpi_report.rolling(window=21).mean()['HALF2'].plot()
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
dataset_test = pd.read_csv('CPI_Report.csv')
dataset_test
# Out:
#     Year      Jan      Feb      Mar      Apr      May      Jun      Jul  \
# 0   2000  168.800  169.800  171.200  171.300  171.500  172.400  172.800
# 1   2001  175.100  175.800  176.200  176.900  177.700  178.000  177.500
# 2   2002  177.100  177.800  178.800  179.800  179.800  179.900  180.100
# 3   2003  181.700  183.100  184.200  183.800  183.500  183.700  183.900
# 4   2004  185.200  186.200  187.400  188.000  189.100  189.700  189.400
# 5   2005  190.700  191.800  193.300  194.600  194.400  194.500  195.400
# 6   2006  198.300  198.700  199.800  201.500  202.500  202.900  203.500
# 7   2007  202.416  203.499  205.352  206.686  207.949  208.352  208.299
# 8   2008  211.080  211.693  213.528  214.823  216.632  218.815  219.964
# 9   2009  211.143  212.193  212.709  213.240  213.856  215.693  215.351
# 10  2010  216.687  216.741  217.631  218.009  218.178  217.965  218.011
# 11  2011  220.223  221.309  223.467  224.906  225.964  225.722  225.922
# ...

# %%
dataset_test.head()
# Out:
#    Year    Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep    Oct  \
# 0  2000  168.8  169.8  171.2  171.3  171.5  172.4  172.8  172.8  173.7  174.0
# 1  2001  175.1  175.8  176.2  176.9  177.7  178.0  177.5  177.5  178.3  177.7
# 2  2002  177.1  177.8  178.8  179.8  179.8  179.9  180.1  180.7  181.0  181.3
# 3  2003  181.7  183.1  184.2  183.8  183.5  183.7  183.9  184.6  185.2  185.0
# 4  2004  185.2  186.2  187.4  188.0  189.1  189.7  189.4  189.5  189.9  190.9
#
#      Nov    Dec  HALF1  HALF2
# 0  174.1  174.0  170.8  173.6
# 1  177.4  176.7  176.6  177.5
# 2  181.3  180.9  178.9  180.9
# 3  184.5  184.3  183.3  184.6
# 4  191.0  190.3  187.6  190.2

# %%
dataset_test.tail()
# Out:
#     Year      Jan      Feb      Mar      Apr      May      Jun      Jul  \
# 18  2018  247.867  248.991  249.554  250.546  251.588  251.989  252.006
# 19  2019  251.712  252.776  254.202  255.548  256.092  256.143  256.571
# 20  2020  257.971  258.678  258.115  256.389  256.394  257.797  259.101
# 21  2021  261.582  263.014  264.877  267.054  269.195  271.696  273.003
# 22  2022  281.148      NaN      NaN      NaN      NaN      NaN      NaN
#
#         Aug      Sep      Oct      Nov      Dec    HALF1    HALF2
# 18  252.146  252.439  252.885  252.038  251.233  250.089  252.125
# 19  256.558  256.759  257.346  257.208  256.974  254.412  256.903
# 20  259.918  260.280  260.388  260.229  260.474  257.557  260.065
# 21  273.567  274.310  276.589  277.948  278.802  266.236  275.703
# 22      NaN      NaN      NaN      NaN      NaN      NaN      NaN

# %%
dataset_test["Year"]=dataset_test["Year"].replace(',', '').astype(float)

# %%
dataset_test["HALF2"]=dataset_test["HALF2"].replace(',', '').astype(float)

# %%
test_set = dataset_test["Jan"]
test_set = pd.DataFrame(test_set)

# %%
test_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Jan     23 non-null     float64
# dtypes: float64(1)
# memory usage: 312.0 bytes

# %%
dataset_total = pd.concat((df_cpi_report['Jan'], dataset_test['Jan']), axis=0)
inputs
